# %% [markdown]
# # seaborn exercises

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
from pydataset import data

# %% [markdown]
# ### Iris dataset

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
# 1. What does the distribution of petal lengths look like?
sns.relplot(x='petal_length', y='petal_width', col='species', data =iris)

# %%
sns.histplot(iris.petal_length, kde=True)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
# 2. Is there a correlation between petal length and petal width? 
#  Use http://guessthecorrelation.com/ as a hint to how we could visually determine 
#  if a correlation exists between two numeric columns.

sns.relplot(x='petal_length', y='petal_width', col='species', data =iris) 

# yes, there is a correlation. the longer the length, the wider it is.

# %%
# 3. Would it be reasonable to predict species based on sepal width and sepal length? 
# For this, you'll visualize two numeric columns through the lense of a categorical column.

sns.relplot(x='sepal_length', y='sepal_width', col='species', data=iris)

# no, it would not be reasonable. Too much overlap.

# %%
sns.relplot(data=iris, x='sepal_length', y='sepal_width', hue='species')

# %%
# 4. Which features would be best used to predict species?

# petal length/width

# %% [markdown]
# ### anscombe dataset

# %%
anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# 1. Using the lesson as an example, use seaborn's load_dataset function to load the 
#  anscombe data set. Use pandas to group the data by the dataset column, and calculate 
#  summary statistics for each dataset. What do you notice?
#       Plot the x and y values from the anscombe data. Each dataset should be 
#       in a separate column.
print('Dataset I') 
dataset_I = anscombe[anscombe['dataset']  == 'I']
print(dataset_I.describe())
print('---------------------------') 

print('Dataset II') 
dataset_II = anscombe[anscombe['dataset']  == 'II']
print(dataset_II.describe())
print('---------------------------') 

print('Dataset III') 
dataset_III = anscombe[anscombe['dataset']  == 'III']
print(dataset_III.describe())
print('---------------------------') 

print('Dataset IV') 
dataset_IV = anscombe[anscombe['dataset']  == 'IV']
print(dataset_IV.describe())
# Out:
# Dataset I
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000
# ---------------------------
# Dataset II
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031657
# min     4.000000   3.100000
# 25%     6.500000   6.695000
# 50%     9.000000   8.140000
# 75%    11.500000   8.950000
# max    14.000000   9.260000
# ---------------------------
# Dataset III
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500000
# std     3.316625   2.030424
# min     4.000000   5.390000
# 25%     6.500000   6.250000
# 50%     9.000000   7.110000
# 75%    11.500000   7.980000
# max    14.000000  12.740000
# ---------------------------
# Dataset IV
#                x          y
# ...

# %%
sns.relplot(x='x', y='y', col= 'dataset', data = anscombe)

# %%
# 2. Load the InsectSprays dataset and read it's documentation. Create a boxplot that 
#  shows the effectiveness of the different insect sprays.

data('InsectSprays', show_doc = True)
# Out:
# InsectSprays
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Effectiveness of Insect Sprays
#
# ### Description
#
# The counts of insects in agricultural experimental units treated with
# different insecticides.
#
# ### Usage
#
#     InsectSprays
#
# ### Format
#
# A data frame with 72 observations on 2 variables.
#
# [,1]
#
# count
#
# numeric
#
# Insect count
#
# [,2]
#
# spray
#
# factor
#
# The type of spray
#
# ### Source
#
# Beall, G., (1942) The Transformation of data from entomological field
# experiments, _Biometrika_, **29**, 243–262.
#
# ### References
#
# McNeil, D. (1977) _Interactive Data Analysis_. New York: Wiley.
#
# ### Examples
#
#     require(stats); require(graphics)
#     boxplot(count ~ spray, data = InsectSprays,
#             xlab = "Type of spray", ylab = "Insect count",
#             main = "InsectSprays data", varwidth = TRUE, col = "lightgray")
#     fm1 <- aov(count ~ spray, data = InsectSprays)
# ...

# %%
insect_sprays = data('InsectSprays')

# %%
insect_sprays
# Out:
#     count spray
# 1      10     A
# 2       7     A
# 3      20     A
# 4      14     A
# 5      14     A
# 6      12     A
# 7      10     A
# 8      23     A
# 9      17     A
# 10     20     A
# 11     14     A
# 12     13     A
# 13     11     B
# 14     17     B
# 15     21     B
# 16     11     B
# 17     16     B
# 18     14     B
# 19     17     B
# 20     17     B
# 21     19     B
# 22     21     B
# 23      7     B
# 24     13     B
# 25      0     C
# 26      1     C
# 27      7     C
# 28      2     C
# 29      3     C
# 30      1     C
# 31      2     C
# 32      1     C
# 33      3     C
# 34      0     C
# 35      1     C
# 36      4     C
# 37      3     D
# 38      5     D
# 39     12     D
# 40      6     D
# 41      4     D
# 42      3     D
# 43      5     D
# 44      5     D
# 45      5     D
# 46      5     D
# 47      2     D
# 48      4     D
# 49      3     E
# 50      5     E
# 51      3     E
# 52      5     E
# 53      3     E
# 54      6     E
# ...

# %%
sns.boxplot(x = 'spray', y = 'count', data = insect_sprays)
# Out:
# <AxesSubplot:xlabel='spray', ylabel='count'>

# %%
# 3. Load the swiss dataset and read it's documentation. The swiss dataset is available 
#   from pydatset rather than seaborn. Create visualizations to answer the following 
#   questions:

# %%
data('swiss', show_doc=True)
# Out:
# swiss
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Swiss Fertility and Socioeconomic Indicators (1888) Data
#
# ### Description
#
# Standardized fertility measure and socio-economic indicators for each of 47
# French-speaking provinces of Switzerland at about 1888.
#
# ### Usage
#
#     data(swiss)
#
# ### Format
#
# A data frame with 47 observations on 6 variables, each of which is in percent,
# i.e., in [0,100].
#
# [,1] Fertility Ig, "common standardized fertility measure" [,2] Agriculture
# [,3] Examination nation [,4] Education [,5] Catholic [,6] Infant.Mortality
# live births who live less than 1 year.
#
# All variables but 'Fert' give proportions of the population.
#
# ### Source
#
# Project "16P5", pages 549-551 in
#
# Mosteller, F. and Tukey, J. W. (1977) “Data Analysis and Regression: A Second
# Course in Statistics”. Addison-Wesley, Reading Mass.
#
# ...

# %%
swiss = data('swiss')
swiss
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# ...

# %%
# 3a. Create an attribute named is_catholic that holds a boolean value of whether or 
#    not the province is Catholic. (Choose a cutoff point for what constitutes catholic)

is_catholic = swiss['Catholic'] >= 65
is_catholic
# Out:
# Courtelary      False
# Delemont         True
# Franches-Mnt     True
# Moutier         False
# Neuveville      False
# Porrentruy       True
# Broye            True
# Glane            True
# Gruyere          True
# Sarine           True
# Veveyse          True
# Aigle           False
# Aubonne         False
# Avenches        False
# Cossonay        False
# Echallens       False
# Grandson        False
# Lausanne        False
# La Vallee       False
# Lavaux          False
# Morges          False
# Moudon          False
# Nyone           False
# Orbe            False
# Oron            False
# Payerne         False
# Paysd'enhaut    False
# Rolle           False
# Vevey           False
# Yverdon         False
# Conthey          True
# Entremont        True
# Herens           True
# Martigwy         True
# Monthey          True
# St Maurice       True
# Sierre           True
# Sion             True
# Boudry          False
# La Chauxdfnd    False
# Le Locle        False
# ...

# %%
swiss['is_catholic'] = is_catholic  # added is_catholic column to DataFrame.
swiss
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# ...

# %%
# 3b. Does whether or not a province is Catholic influence fertility?

sns.boxplot(x='is_catholic', y='Fertility', data=swiss)
# Out:
# <AxesSubplot:xlabel='is_catholic', ylabel='Fertility'>

# %%
# 3c. What measure correlates most strongly with fertility?

sns.boxplot(x='is_catholic', y='Agriculture', data=swiss)
# Out:
# <AxesSubplot:xlabel='is_catholic', ylabel='Agriculture'>

# %%
import env
import os

# %%
def get_db_url(db, env_file = os.path.exists('env.py')):
    '''
    return a formatted string containing username, password, host, and database for connecting to the mySQL server
    and the database indicated.
    env_file checks to see if the env.py exists in cwd
    '''
    if env_file:
        username, password, host = (env.username, env.password, env.host)
        return f'mysql+pymysql://{username}:{password}@{host}/{db}'
    else:
        return 'hello, you need a username and password to get in.'
    
url = get_db_url('chipotle')

# %%
# 4. Using the chipotle dataset from the previous exercise, create a bar chart that 
#  shows the 4 most popular items and the revenue produced by each.

chipotle = pd.read_sql('SELECT * FROM orders', url)

# %%
chipotle.head(10)
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
# 5   6         3         1                           Chicken Bowl
# 6   7         3         1                          Side of Chips
# 7   8         4         1                          Steak Burrito
# 8   9         4         1                       Steak Soft Tacos
# 9  10         5         1                          Steak Burrito
#
#                                                                           choice_description  \
# 0                                                                                        nan
# ...

# %%
pre_total = chipotle.groupby(['item_name','item_price'])['quantity'].sum().sort_values(ascending = False)

big_money = pd.DataFrame(pre_total) 

# couldnt pull item_name because it was my index. reset it using df.reset_index(drop=False). Use True if you want
# to replace current index.

# %%
big_money = big_money.reset_index(drop=False)
big_money
# Out:
#                item_name item_price  quantity
# 0    Chips and Guacamole     $4.45        349
# 1           Chicken Bowl     $8.75        313
# 2      Canned Soft Drink     $1.25        264
# 3        Chicken Burrito     $8.75        230
# 4           Chicken Bowl    $11.25        228
# ..                   ...        ...       ...
# 204        Chicken Salad     $8.19          1
# 205       Carnitas Salad     $8.99          1
# 206   Steak Crispy Tacos     $8.69          1
# 207         Chicken Bowl    $10.58          1
# 208     Carnitas Burrito    $11.08          1
#
# [209 rows x 3 columns]

# %%
bm_t4 = big_money.head(4)
bm_t4
# Out:
#              item_name item_price  quantity
# 0  Chips and Guacamole     $4.45        349
# 1         Chicken Bowl     $8.75        313
# 2    Canned Soft Drink     $1.25        264
# 3      Chicken Burrito     $8.75        230

# %%
item_price_float = bm_t4['item_price'].str.replace('$','').astype('float')

bm_t4['item_price_float'] = item_price_float
bm_t4
# Out:
# /var/folders/86/j98_vzjs5dg0v5262tfx5yhw0000gn/T/ipykernel_77813/675572913.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   item_price_float = bm_t4['item_price'].str.replace('$','').astype('float')
# /var/folders/86/j98_vzjs5dg0v5262tfx5yhw0000gn/T/ipykernel_77813/675572913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bm_t4['item_price_float'] = item_price_float
#              item_name item_price  quantity  item_price_float  revenue
# 0  Chips and Guacamole     $4.45        349              4.45  1553.05
# ...

# %%
revenue = bm_t4['quantity'] * bm_t4['item_price_float']
revenue
bm_t4['revenue'] = revenue

bm_t4
# Out:
# /var/folders/86/j98_vzjs5dg0v5262tfx5yhw0000gn/T/ipykernel_77813/667740442.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bm_t4['revenue'] = revenue
#              item_name item_price  quantity  item_price_float  revenue
# 0  Chips and Guacamole     $4.45        349              4.45  1553.05
# 1         Chicken Bowl     $8.75        313              8.75  2738.75
# 2    Canned Soft Drink     $1.25        264              1.25   330.00
# 3      Chicken Burrito     $8.75        230              8.75  2012.50

# %%
sns.barplot(x='item_name', y='revenue', data=bm_t4)
plt.xticks(rotation=40)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Chips and Guacamole'),
#   Text(1, 0, 'Chicken Bowl'),
#   Text(2, 0, 'Canned Soft Drink'),
#   Text(3, 0, 'Chicken Burrito')])

# %%
# 5. Load the sleepstudy data and read it's documentation. Use seaborn to create a line 
#   chart of all the individual subject's reaction times and a more prominant line 
#   showing the average change in reaction time.

data('sleepstudy',show_doc=True)
# Out:
# sleepstudy
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Reaction times in a sleep deprivation study
#
# ### Description
#
# The average reaction time per day for subjects in a sleep deprivation study.
# On day 0 the subjects had their normal amount of sleep. Starting that night
# they were restricted to 3 hours of sleep per night. The observations represent
# the average reaction time on a series of tests given each day to each subject.
#
# ### Format
#
# A data frame with 180 observations on the following 3 variables.
#
# `Reaction`
#
# Average reaction time (ms)
#
# `Days`
#
# Number of days of sleep deprivation
#
# `Subject`
#
# Subject number on which the observation was made.
#
# ### Details
#
# These data are from the study described in Belenky et al. (2003), for the
# sleep-deprived group and for the first 10 days of the study, up to the
# recovery period.
#
# ### References
#
# ...

# %%
sleepy = data('sleepstudy')

# %%
sleepy
# Out:
#      Reaction  Days  Subject
# 1    249.5600     0      308
# 2    258.7047     1      308
# 3    250.8006     2      308
# 4    321.4398     3      308
# 5    356.8519     4      308
# ..        ...   ...      ...
# 176  329.6076     5      372
# 177  334.4818     6      372
# 178  343.2199     7      372
# 179  369.1417     8      372
# 180  364.1236     9      372
#
# [180 rows x 3 columns]

# %%
sleepy['Subject'].unique()
# Out:
# array([308, 309, 310, 330, 331, 332, 333, 334, 335, 337, 349, 350, 351,
#        352, 369, 370, 371, 372])

# %%
# 5. Load the sleepstudy data and read it's documentation. Use seaborn to create a line chart of all the 
#   individual subject's reaction times and a more prominant line showing the average change in reaction time.

one = sleepy[sleepy['Subject'].isin([308])]
two = sleepy[sleepy['Subject'].isin([309])]
three = sleepy[sleepy['Subject'].isin([310])]
four = sleepy[sleepy['Subject'].isin([330])]
five = sleepy[sleepy['Subject'].isin([331])]
six = sleepy[sleepy['Subject'].isin([332])]        
seven = sleepy[sleepy['Subject'].isin([333])]
eight = sleepy[sleepy['Subject'].isin([334])]
nine = sleepy[sleepy['Subject'].isin([335])]
ten = sleepy[sleepy['Subject'].isin([337])]

things = {'one': one, 'two': two, 'three': three,'four':four}
things

#tried using dictionary for multiple lines in lineplot. not working out.
# Out:
# {'one':     Reaction  Days  Subject
#  1   249.5600     0      308
#  2   258.7047     1      308
#  3   250.8006     2      308
#  4   321.4398     3      308
#  5   356.8519     4      308
#  6   414.6901     5      308
#  7   382.2038     6      308
#  8   290.1486     7      308
#  9   430.5853     8      308
#  10  466.3535     9      308,
#  'two':     Reaction  Days  Subject
#  11  222.7339     0      309
#  12  205.2658     1      309
#  13  202.9778     2      309
#  14  204.7070     3      309
#  15  207.7161     4      309
#  16  215.9618     5      309
#  17  213.6303     6      309
#  18  217.7272     7      309
#  19  224.2957     8      309
#  20  237.3142     9      309,
#  'three':     Reaction  Days  Subject
#  21  199.0539     0      310
#  22  194.3322     1      310
#  23  234.3200     2      310
#  24  232.8416     3      310
#  25  229.3074     4      310
#  26  220.4579     5      310
#  27  235.4208     6      310
#  28  255.7511     7      310
# ...

# %%
sleepy2 = sleepy[(sleepy['Subject'] == 308) | (sleepy['Subject'] == 330)]

# %%
sns.lineplot(x='Days', y='Reaction', data=sleepy2, hue = 'Subject', estimator=np.median)
# Out:
# <AxesSubplot:xlabel='Days', ylabel='Reaction'>

# %%
sns.lineplot(x='Days', y='Reaction', data=sleepy, hue = 'Subject', estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='Days', ylabel='Reaction'>
